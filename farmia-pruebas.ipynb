# %%
spark.range(5).show()

# %%
from ingesta.config import load_config

print("Importación correcta")

# %%
account = spark.conf.get("adls.account.name")
print(account)

# %%
display(dbutils.fs.ls("abfss://datos@mastermsg0001sts.dfs.core.windows.net/"))
